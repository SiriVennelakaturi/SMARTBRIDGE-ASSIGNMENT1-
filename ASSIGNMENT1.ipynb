# %% [markdown]
# <a href="https://colab.research.google.com/github/SiriVennelakaturi/SMARTBRIDGE-ASSIGNMENT1-/blob/main/ASSIGNMENT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Basic python

# %% [markdown]
# #Task1
# write a python program to check if a number is even or odd.

# %%
num=int(input("enter an integer:"))
if num%2==0:
   print("even")
else:
  print("odd")
# Out:
# enter an integer:9
# odd

# %% [markdown]
# #Task2
# write a python program to find the largest of three numbers.

# %%
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
num3=int(input("enter third number:"))
if num1>num2 and num1>num3:
  print(num1,"is greatest")
elif num2>num1 and num2>num3:
  print(num2,"is greatest")
else:
  print(num3,"is greatest")
# Out:
# enter first number:12
# enter second number:13
# enter third number:11
# 13 is greatest

# %% [markdown]
# #Numpy

# %% [markdown]
# #Task1
# create a NumPy array of shape (3,3) filled with random numbers. then compute the mean,median,and standard deviation of the array.

# %%
import numpy as np
#create a numpy array of shape (3,3) filled with random numbers
arr=np.random.randint(1,100,(3,3))
arr
# Out:
# array([[51, 13,  9],
#        [78, 58, 28],
#        [57,  8, 14]])

# %% [markdown]
# #mean

# %%
#mean
np.mean(arr)#overall mean calculation
# Out:
# 35.111111111111114

# %%
np.mean(arr,axis=0)#column wise mean calculation
# Out:
# array([62.        , 26.33333333, 17.        ])

# %%
np.mean(arr,axis=1)#row wise mean calculation
# Out:
# array([24.33333333, 54.66666667, 26.33333333])

# %% [markdown]
# #median

# %%
#median
np.median(arr)#overall median calculation
# Out:
# 28.0

# %%
np.median(arr,axis=0)#column wise median calculation
# Out:
# array([57., 13., 14.])

# %%
np.median(arr,axis=1)#row wise median calculation
# Out:
# array([13., 58., 14.])

# %% [markdown]
# #standard deviation

# %%
np.std(arr)#overall standard deviation calculation
# Out:
# 24.713668932369497

# %%
np.std(arr,axis=0)#column wise standard deviation calculation
# Out:
# array([11.5758369 , 22.48456261,  8.04155872])

# %%
np.std(arr,axis=1)#row wise standard deviation calculation
# Out:
# array([18.92675942, 20.54804668, 21.8225164 ])

# %% [markdown]
# #Task2

# %% [markdown]
# #multiplication of two 2X2 matrices

# %%
#perform matrix multiplication using numpy
#create 2X2 matrices and multiply them. print the result
import numpy as np
a=np.array([1,3,6,7])
a=a.reshape(2,2)
a
# Out:
# array([[1, 3],
#        [6, 7]])

# %%
b=np.array([10,20,30,40])
b=b.reshape(2,2)
b
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
res=np.multiply(a,b)#multiplication of the two 2X2 matrices
res
# Out:
# array([[ 10,  60],
#        [180, 280]])

# %% [markdown]
# #Pandas

# %% [markdown]
# #Task1
# load a csv file into a pandas dataframe and display its first 5 rows.provide basic statistics of the dataset using the describe() Mrthod.

# %%
import pandas as pd
df=pd.read_csv('/content/mtcars.csv')
df.head(5)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#describe()
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# #Task2
# filter the Dataframe based on a condition
# for example,filter rows where a specific column value is greater than a threshold. Display the filtered DataFrame

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.loc[df["hp"]>100]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# ...

# %% [markdown]
# ##Matplotlib

# %% [markdown]
# #Task1
# create a line plot using Matplotlib.
# plot the function y=x^2 for x values ranging from -10 to 10. Label the

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(-10,11)
y=x^2
plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Line Plot")
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %% [markdown]
# #Task2
# create a bar chart using matplotlib.
# bar chart for number of students in different branches

# %%
branch=['CSE','EEE','AIML','AIDS','ME','CE']
students=[450,320,280,470,290,300]
students
# Out:
# [450, 320, 280, 470, 290, 300]

# %%
plt.bar(branch,students)
plt.xlabel("Branch")
plt.ylabel("students")
plt.title("No. of students in each branch")
# Out:
# Text(0.5, 1.0, 'No. of students in each branch')

# %% [markdown]
# #SEABORN

# %% [markdown]
# #TASK1
# create a histogram using seaborn.

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #Task2
# create a heatmap using seaborn.
# Use a a correlation matrix of a dataset to create a heatmap.Annotate the heatmap for better readibility.

# %%
df1=df[["mpg","cyl"]]
df1
# Out:
#      mpg  cyl
# 0   21.0    6
# 1   21.0    6
# 2   22.8    4
# 3   21.4    6
# 4   18.7    8
# 5   18.1    6
# 6   14.3    8
# 7   24.4    4
# 8   22.8    4
# 9   19.2    6
# 10  17.8    6
# 11  16.4    8
# 12  17.3    8
# 13  15.2    8
# 14  10.4    8
# 15  10.4    8
# 16  14.7    8
# 17  32.4    4
# 18  30.4    4
# 19  33.9    4
# 20  21.5    4
# 21  15.5    8
# 22  15.2    8
# 23  13.3    8
# 24  19.2    8
# 25  27.3    4
# 26  26.0    4
# 27  30.4    4
# 28  15.8    8
# 29  19.7    6
# 30  15.0    8
# 31  21.4    4

# %%
sns.heatmap(df1.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >
